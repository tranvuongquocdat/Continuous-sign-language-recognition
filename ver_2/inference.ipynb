# %%
import datetime
from ultralytics import YOLO
import cv2

# Load the pre-trained YOLOv8n model
model = YOLO(r"models\yolov8n_sign_language.pt")

id = 0
video_cap = cv2.VideoCapture(id)

def draw_detections(frame, last_detections):
    # Define some constants
    CONFIDENCE_THRESHOLD = 0.8
    COLOR = (153, 255, 204)
    if last_detections is not None:
        for data in last_detections.boxes.data.tolist():
            # Extract the confidence (i.e., probability) associated with the detection
            confidence = data[4]

            # Filter out weak detections by ensuring the 
            # confidence is greater than the minimum confidence
            if float(confidence) < CONFIDENCE_THRESHOLD:
                continue

            # If the confidence is greater than the minimum confidence,
            # draw the bounding box on the frame
            xmin, ymin, xmax, ymax = int(data[0]), int(data[1]), int(data[2]), int(data[3])
            cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), COLOR, 2)

            # Get the class ID and draw it on the frame
            class_id = data[5]
            text = f"{class_id}, {confidence:.2f}"
            cv2.putText(frame, text, (xmin, ymin - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR, 2)

    return frame

prev_time = datetime.datetime.now()

while True:
    ret, frame = video_cap.read()
    if not ret:
        break
    
    frame = cv2.flip(frame, 1)
    detections = model(frame)[0]
    frame = draw_detections(frame, detections)

    # Calculate FPS
    curr_time = datetime.datetime.now()
    delta_time = curr_time - prev_time
    fps = 1 / delta_time.total_seconds()
    prev_time = curr_time

    # Display FPS on the frame
    fps_text = f"FPS: {fps:.2f}"
    cv2.putText(frame, fps_text, (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    cv2.imshow("Image", frame)
    if cv2.waitKey(1) == ord('q'):
        break

video_cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 0.0ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 2.1ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 0.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 0.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 0.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.5ms
# Speed: 2.1ms preprocess, 3.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.1ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 1.1ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 5.2ms
# Speed: 0.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 1 M, 3.1ms
# Speed: 1.0ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 4.6ms
# Speed: 0.0ms preprocess, 4.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 3.1ms
# Speed: 2.1ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 1 M, 4.1ms
# Speed: 2.3ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 1 E, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 1 E, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 1 E, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 1 E, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 5.5ms
# Speed: 0.0ms preprocess, 5.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 5.9ms
# Speed: 1.0ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 E, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 5.2ms
# Speed: 2.1ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 3.1ms
# Speed: 1.0ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.8ms
# Speed: 2.0ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 0.1ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.9ms
# Speed: 1.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.8ms
# Speed: 0.5ms preprocess, 7.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.3ms
# Speed: 0.0ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.3ms
# Speed: 0.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.6ms
# Speed: 1.0ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 0.0ms preprocess, 5.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.2ms
# Speed: 0.0ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 0.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.2ms
# Speed: 0.0ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.2ms
# Speed: 1.1ms preprocess, 7.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.6ms
# Speed: 1.0ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 B, 8.4ms
# Speed: 1.2ms preprocess, 8.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 B, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 F, 1 K, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.2ms
# Speed: 2.3ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.3ms
# Speed: 1.2ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.3ms
# Speed: 2.0ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.6ms
# Speed: 2.8ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Os, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 10.3ms
# Speed: 3.2ms preprocess, 10.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.4ms
# Speed: 1.1ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 2.0ms preprocess, 5.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 2.1ms preprocess, 5.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.2ms
# Speed: 0.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 2.6ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 5.1ms
# Speed: 0.5ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.3ms
# Speed: 2.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 9.8ms
# Speed: 1.0ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 0.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 2.1ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 F, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 F, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 F, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 0.5ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 C, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 5.9ms
# Speed: 1.0ms preprocess, 5.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 1 W, 5.4ms
# Speed: 2.1ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.2ms
# Speed: 0.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.2ms
# Speed: 2.5ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.4ms
# Speed: 0.0ms preprocess, 7.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.4ms
# Speed: 2.1ms preprocess, 5.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 4.7ms
# Speed: 2.1ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.2ms
# Speed: 2.1ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 7.2ms
# Speed: 1.1ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Os, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.1ms
# Speed: 0.5ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 4.1ms
# Speed: 0.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 4.2ms
# Speed: 2.1ms preprocess, 4.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.3ms
# Speed: 2.0ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 5.7ms
# Speed: 0.0ms preprocess, 5.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.1ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 0.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 O, 6.4ms
# Speed: 0.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Q, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 0.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 7.4ms
# Speed: 1.1ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 M, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
import numpy as np

# Giả sử đây là mảng numpy của bạn
arr = np.array([1, 2, 3, 2, 4, 5, 2, 6, 2, 7])

# Sử dụng np.unique để lấy các phần tử duy nhất và số lần xuất hiện của chúng
values, counts = np.unique(arr, return_counts=True)

# Tìm chỉ số của phần tử có số lần xuất hiện nhiều nhất
index_of_most_common = np.argmax(counts)

# Phần tử xuất hiện nhiều nhất
most_common_element = values[index_of_most_common]

print(f'Phần tử xuất hiện nhiều nhất là {most_common_element} với {counts[index_of_most_common]} lần xuất hiện.')
# Out:
# Phần tử xuất hiện nhiều nhất là 2 với 4 lần xuất hiện.

# %%
sign_arr = np.empty(0)

sign_arr = np.append(sign_arr, 1)
sign_arr = np.append(sign_arr, 1)
sign_arr
# Out:
# array([          1,           1])

# %%
def numpy_array_to_string(arr):
    return ' '.join(map(str, arr))

# %%
arr = numpy_array_to_string(sign_arr)
arr
# Out:
# '1.0 1.0'

# %%
import cv2
import mediapipe as mp
import numpy as np
import datetime
from ultralytics import YOLO
import collections
from PIL import ImageFont, ImageDraw, Image

# Load the pre-trained YOLOv8n model
model = YOLO(r"models\yolov8n_sign_language.pt")

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Initialize MediaPipe drawing utils for drawing hands on the image
mp_drawing = mp.solutions.drawing_utils

def draw_detections(frame, last_detections):
    CONFIDENCE_THRESHOLD = 0.7
    COLOR = (153, 255, 204)
    result = 99
    if last_detections is not None:
        for data in last_detections.boxes.data.tolist():
            confidence = data[4]
            if float(confidence) < CONFIDENCE_THRESHOLD:
                continue
            xmin, ymin, xmax, ymax = int(data[0]), int(data[1]), int(data[2]), int(data[3])
            cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), COLOR, 2)
            class_id = data[5]
            result = class_id
            text = f"{class_id}, {confidence:.2f}"
            cv2.putText(frame, text, (xmin, ymin - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR, 2)
    return frame, result

def numpy_array_to_string(arr):
    return ' '.join(map(str, arr))

def put_vietnamese_text(img, text, position, font_path, font_size, color):
    # Chuyển đổi hình ảnh từ OpenCV sang PIL
    pil_img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(pil_img)
    font = ImageFont.truetype(font_path, font_size)
    draw.text(position, text, font=font, fill=color)

    # Chuyển đổi hình ảnh từ PIL sang OpenCV
    img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    return img

label_map = {0: "Toi",
             1: "",
             2: "com",
             3: "",
             4: "",
             5: "",
             6: "",
             7: "",
             8: "",
             9: "",
             10: "ban",
             11: "",
             12: "",
             13: "",
             14: "an",
             15: "",
             16: "",
             17: "",
             18: "",
             19: "",
             20: "di",
             21: "choi",
             22: "chao",
             23: "",
             24: "",
             25: "",
             26: "",
             27: "",
             28: "",
             29: "",
             30: "",
             }

prev_time = datetime.datetime.now()

# Create a VideoCapture object to capture the video from your webcam
id = 0
cap = cv2.VideoCapture(id)

sign_arr = np.empty(0)
pred_count = 0
result_arr = []
max_empty_hand_frame = 30
empty_hand_frame = 0
current_result = 88
font_path = "Disney.ttf"
result = 0

# Define a deque to store the last N results for smoothing
N = 10  # Size of the sliding window
result_buffer = collections.deque(maxlen=N)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        continue

    # Convert the frame color from BGR to RGB
    frame = cv2.flip(frame, 1)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame to detect hands
    results = hands.process(frame_rgb)

    if results.multi_hand_landmarks:
        empty_hand_frame = 0
        for hand_landmarks in results.multi_hand_landmarks:

            h, w, _ = frame.shape
            x_min = w
            x_max = 0
            y_min = h
            y_max = 0
            for lm in hand_landmarks.landmark:
                x, y = int(lm.x * w), int(lm.y * h)
                if x < x_min:
                    x_min = x
                if x > x_max:
                    x_max = x
                if y < y_min:
                    y_min = y
                if y > y_max:
                    y_max = y

            expand_width = int((x_max - x_min) * 0.8)
            expand_height = int((y_max - y_min) * 0.8)
            x_min = max(0, x_min - expand_width)
            x_max = min(w, x_max + expand_width)
            y_min = max(0, y_min - expand_height)
            y_max = min(h, y_max + expand_height)

            cropped_image = frame[y_min:y_max, x_min:x_max]
            detections = model(cropped_image)[0]
            cropped_image, result = draw_detections(cropped_image, detections)

            if result != 99:
                result_buffer.append(result)

            cv2.imshow("Image", cropped_image)
            mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    else:
        empty_hand_frame += 1

    if len(result_buffer) > 0:
        # Use the most common element in the buffer as the stable result
        result = max(set(result_buffer), key=result_buffer.count)
        if result != current_result:
            sign_arr = np.append(sign_arr, label_map[result])
            current_result = result

    if empty_hand_frame == max_empty_hand_frame:
        if result == 0:
            current_result = 88
        else:
            current_result = result
        sign_arr = np.empty(0)
    
    curr_time = datetime.datetime.now()
    delta_time = curr_time - prev_time
    fps = 1 / delta_time.total_seconds()
    prev_time = curr_time

    # Display FPS on the frame
    FPS_COLOR = (153, 255, 204)
    fps_text = f"FPS: {fps:.2f}"
    cv2.putText(frame, fps_text, (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, FPS_COLOR, 2)

    # Create a separate window for displaying the results
    result_window = np.zeros((80, 1000, 3), dtype=np.uint8)
    show_result = numpy_array_to_string(sign_arr)
    cv2.putText(result_window, str(show_result), (10, 50), cv2.FONT_HERSHEY_COMPLEX, 1.5, (255, 255, 255), 2)

    cv2.imshow('Hand Detection', frame)
    cv2.imshow("Result window", result_window)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and destroy all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 (no detections), 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.5ms
# Speed: 2.8ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 (no detections), 26.5ms
# Speed: 3.0ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x576 1 E, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x544 1 M, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x544 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x544 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x576 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x640 (no detections), 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 E, 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 21.5ms
# Speed: 3.5ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 21.2ms
# Speed: 4.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 3.2ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x352 1 K, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 K, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 K, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 K, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x320 1 K, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x320 1 K, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x512 1 V, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 16.5ms
# Speed: 3.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 V, 17.0ms
# Speed: 3.2ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x480 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x352 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x320 1 K, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x320 1 K, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 1 U, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 1 U, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 1 U, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 1 U, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 1 U, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 1 U, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 1 K, 1 U, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x320 1 K, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x352 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x384 1 K, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 K, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x416 1 K, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x448 1 K, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 K, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x416 1 K, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x448 1 K, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x416 1 K, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x448 1 K, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x416 1 K, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 K, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x640 (no detections), 35.0ms
# Speed: 5.2ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 34.0ms
# Speed: 5.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 36.0ms
# Speed: 8.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 29.5ms
# Speed: 5.0ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 5.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 10.0ms
# Speed: 3.4ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x576 1 E, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 E, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x608 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 1 E, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 M, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 1 O, 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 22.0ms
# Speed: 5.0ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 23.0ms
# Speed: 5.0ms preprocess, 23.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x576 1 P, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 C, 1 P, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 C, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x544 1 C, 1 P, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x576 1 C, 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x544 1 C, 1 P, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x576 1 P, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 C, 1 P, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x544 1 C, 1 P, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x576 1 P, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 P, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 1 P, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 1 P, 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 P, 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 1 P, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 23.0ms
# Speed: 8.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 22.5ms
# Speed: 4.8ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 11.0ms
# Speed: 4.3ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x608 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x576 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x608 (no detections), 30.0ms
# Speed: 4.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 1 O, 26.0ms
# Speed: 4.4ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 O, 26.0ms
# Speed: 5.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 1 O, 24.5ms
# Speed: 4.0ms preprocess, 24.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 23.0ms
# Speed: 5.0ms preprocess, 23.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 O, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 P, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 P, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 1 P, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 544x640 (no detections), 31.5ms
# Speed: 2.5ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 1 O, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 O, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 544x640 (no detections), 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 O, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 1 P, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 C, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 O, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 O, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 C, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 (no detections), 25.1ms
# Speed: 5.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 I, 25.0ms
# Speed: 4.0ms preprocess, 25.0ms inference, 4.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 I, 24.0ms
# Speed: 5.0ms preprocess, 24.0ms inference, 6.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 26.2ms
# Speed: 5.0ms preprocess, 26.2ms inference, 2.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 1 E, 25.5ms
# Speed: 3.5ms preprocess, 25.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 E, 24.0ms
# Speed: 5.0ms preprocess, 24.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 (no detections), 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 (no detections), 13.0ms
# Speed: 2.7ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 416x640 (no detections), 41.0ms
# Speed: 2.0ms preprocess, 41.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 352x640 (no detections), 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 320x640 (no detections), 31.2ms
# Speed: 2.0ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 288x640 (no detections), 34.0ms
# Speed: 2.1ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)

# %%
import socket
import cv2
import numpy as np
import struct



while True:
    while len(data) < payload_size:
        data += client_socket.recv(4096)

    packed_msg_size = data[:payload_size]
    data = data[payload_size:]
    msg_size = struct.unpack("<L", packed_msg_size)[0]

    while len(data) < msg_size:
        data += client_socket.recv(4096)

    frame_data = data[:msg_size]
    data = data[msg_size:]

    # Giải mã hình ảnh
    frame = cv2.imdecode(np.frombuffer(frame_data, dtype=np.uint8), cv2.IMREAD_COLOR)
    frame = cv2.flip(frame, 1)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # Hiển thị hình ảnh
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

client_socket.close()
cv2.destroyAllWindows()

# %%
import socket
import struct
import cv2
import mediapipe as mp
import numpy as np
import datetime
from ultralytics import YOLO
import collections
from PIL import ImageFont, ImageDraw, Image

# Load the pre-trained YOLOv8n model
model = YOLO(r"runs\detect\train9\weights\best.pt")

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Thiết lập socket client
client_socket = socket.socket()
client_socket.connect(('172.20.10.12', 8000))

# Nhận dữ liệu hình ảnh từ server
data = b""
payload_size = struct.calcsize("<L")

# Initialize MediaPipe drawing utils for drawing hands on the image
mp_drawing = mp.solutions.drawing_utils

def draw_detections(frame, last_detections):
    CONFIDENCE_THRESHOLD = 0.7
    COLOR = (153, 255, 204)
    result = 99
    if last_detections is not None:
        for data in last_detections.boxes.data.tolist():
            confidence = data[4]
            if float(confidence) < CONFIDENCE_THRESHOLD:
                continue
            xmin, ymin, xmax, ymax = int(data[0]), int(data[1]), int(data[2]), int(data[3])
            cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), COLOR, 2)
            class_id = data[5]
            result = class_id
            text = f"{class_id}, {confidence:.2f}"
            cv2.putText(frame, text, (xmin, ymin - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR, 2)
    return frame, result

def numpy_array_to_string(arr):
    return ' '.join(map(str, arr))

def put_vietnamese_text(img, text, position, font_path, font_size, color):
    # Chuyển đổi hình ảnh từ OpenCV sang PIL
    pil_img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(pil_img)
    font = ImageFont.truetype(font_path, font_size)
    draw.text(position, text, font=font, fill=color)

    # Chuyển đổi hình ảnh từ PIL sang OpenCV
    img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    return img

label_map = {0: "Toi",
             1: "",
             2: "com",
             3: "",
             4: "",
             5: "",
             6: "",
             7: "",
             8: "",
             9: "",
             10: "ban",
             11: "",
             12: "",
             13: "",
             14: "an",
             15: "",
             16: "",
             17: "",
             18: "",
             19: "",
             20: "di",
             21: "choi",
             22: "chao",
             23: "",
             24: "",
             25: "",
             26: "",
             27: "",
             28: "",
             29: "",
             30: "",
             }

prev_time = datetime.datetime.now()

sign_arr = np.empty(0)
pred_count = 0
result_arr = []
max_empty_hand_frame = 30
empty_hand_frame = 0
current_result = 88
font_path = "Disney.ttf"
result = 0

# Define a deque to store the last N results for smoothing
N = 10  # Size of the sliding window
result_buffer = collections.deque(maxlen=N)

while True:
    while len(data) < payload_size:
        data += client_socket.recv(4096)

    packed_msg_size = data[:payload_size]
    data = data[payload_size:]
    msg_size = struct.unpack("<L", packed_msg_size)[0]

    while len(data) < msg_size:
        data += client_socket.recv(4096)

    frame_data = data[:msg_size]
    data = data[msg_size:]

    # Giải mã hình ảnh
    frame = cv2.imdecode(np.frombuffer(frame_data, dtype=np.uint8), cv2.IMREAD_COLOR)

    # Convert the frame color from BGR to RGB
    frame = cv2.flip(frame, 1)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame to detect hands
    results = hands.process(frame_rgb)

    if results.multi_hand_landmarks:
        empty_hand_frame = 0
        for hand_landmarks in results.multi_hand_landmarks:

            h, w, _ = frame.shape
            x_min = w
            x_max = 0
            y_min = h
            y_max = 0
            for lm in hand_landmarks.landmark:
                x, y = int(lm.x * w), int(lm.y * h)
                if x < x_min:
                    x_min = x
                if x > x_max:
                    x_max = x
                if y < y_min:
                    y_min = y
                if y > y_max:
                    y_max = y

            expand_width = int((x_max - x_min) * 0.8)
            expand_height = int((y_max - y_min) * 0.8)
            x_min = max(0, x_min - expand_width)
            x_max = min(w, x_max + expand_width)
            y_min = max(0, y_min - expand_height)
            y_max = min(h, y_max + expand_height)

            cropped_image = frame[y_min:y_max, x_min:x_max]
            # cropped_image = frame
            detections = model(cropped_image)[0]
            cropped_image, result = draw_detections(cropped_image, detections)

            if result != 99:
                result_buffer.append(result)

            cv2.imshow("Image", cropped_image)
            mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    else:
        empty_hand_frame += 1

    if len(result_buffer) > 0:
        # Use the most common element in the buffer as the stable result
        result = max(set(result_buffer), key=result_buffer.count)
        if result != current_result:
            sign_arr = np.append(sign_arr, label_map[result])
            current_result = result

    if empty_hand_frame == max_empty_hand_frame:
        if result == 0:
            current_result = 88
        else:
            current_result = result
        sign_arr = np.empty(0)
    
    curr_time = datetime.datetime.now()
    delta_time = curr_time - prev_time
    fps = 1 / delta_time.total_seconds()
    prev_time = curr_time

    # Display FPS on the frame
    FPS_COLOR = (153, 255, 204)
    fps_text = f"FPS: {fps:.2f}"
    cv2.putText(frame, fps_text, (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, FPS_COLOR, 2)

    # Create a separate window for displaying the results
    result_window = np.zeros((80, 1000, 3), dtype=np.uint8)
    show_result = numpy_array_to_string(sign_arr)
    cv2.putText(result_window, str(show_result), (10, 50), cv2.FONT_HERSHEY_COMPLEX, 1.5, (255, 255, 255), 2)

    cv2.imshow('Hand Detection', frame)
    cv2.imshow("Result window", result_window)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and destroy all OpenCV windows
client_socket.close()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 A, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 47.3ms
# Speed: 1.0ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 113.9ms
# Speed: 1.0ms preprocess, 113.9ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 81.2ms
# Speed: 2.0ms preprocess, 81.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 173.9ms
# Speed: 3.0ms preprocess, 173.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 103.2ms
# Speed: 2.0ms preprocess, 103.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 1 W, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 1 W, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 1 W, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Y, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 19.0ms
# Speed: 1.2ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 30.1ms
# Speed: 1.4ms preprocess, 30.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.2ms
# Speed: 2.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.1ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 18.6ms
# Speed: 1.1ms preprocess, 18.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 29.2ms
# Speed: 1.0ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 48.0ms
# Speed: 2.0ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.5ms
# Speed: 1.5ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 1 V, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 49.5ms
# Speed: 2.0ms preprocess, 49.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.5ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 49.6ms
# Speed: 2.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 48.0ms
# Speed: 2.0ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.4ms
# Speed: 1.0ms preprocess, 20.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.4ms
# Speed: 1.0ms preprocess, 20.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 49.8ms
# Speed: 2.0ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 172.0ms
# Speed: 2.0ms preprocess, 172.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.3ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 1 E, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 130.1ms
# Speed: 2.0ms preprocess, 130.1ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 P, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 1 P, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 1 W, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 U, 1 W, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.5ms
# Speed: 2.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 W, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 V, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.3ms
# Speed: 2.0ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 26.1ms
# Speed: 1.0ms preprocess, 26.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 K, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 216.7ms
# Speed: 2.0ms preprocess, 216.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 210
#     208 # Release the capture and destroy all OpenCV windows
#     209 client_socket.close()
# --> 210 cap.release()
#     211 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined

# %%
import socket
import struct
import cv2
import mediapipe as mp
import numpy as np
import datetime
from ultralytics import YOLO
import collections
from PIL import ImageFont, ImageDraw, Image

# Load the pre-trained YOLOv8n model
model = YOLO(r"runs\detect\train9\weights\best.pt")

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Thiết lập socket client
client_socket = socket.socket()
client_socket.connect(('172.20.10.12', 8000))

# Nhận dữ liệu hình ảnh từ server
data = b""
payload_size = struct.calcsize("<L")

# Initialize MediaPipe drawing utils for drawing hands on the image
mp_drawing = mp.solutions.drawing_utils

def draw_detections(frame, last_detections):
    CONFIDENCE_THRESHOLD = 0.7
    COLOR = (153, 255, 204)
    result = 99
    if last_detections is not None:
        for data in last_detections.boxes.data.tolist():
            confidence = data[4]
            if float(confidence) < CONFIDENCE_THRESHOLD:
                continue
            xmin, ymin, xmax, ymax = int(data[0]), int(data[1]), int(data[2]), int(data[3])
            cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), COLOR, 2)
            class_id = data[5]
            result = class_id
            text = f"{class_id}, {confidence:.2f}"
            cv2.putText(frame, text, (xmin, ymin - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR, 2)
    return frame, result

def numpy_array_to_string(arr):
    return ' '.join(map(str, arr))

def put_vietnamese_text(img, text, position, font_path, font_size, color):
    # Chuyển đổi hình ảnh từ OpenCV sang PIL
    pil_img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(pil_img)
    font = ImageFont.truetype(font_path, font_size)
    draw.text(position, text, font=font, fill=color)

    # Chuyển đổi hình ảnh từ PIL sang OpenCV
    img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    return img

label_map = {0: "Toi",
             1: "",
             2: "com",
             3: "",
             4: "",
             5: "",
             6: "",
             7: "",
             8: "",
             9: "",
             10: "ban",
             11: "",
             12: "",
             13: "",
             14: "an",
             15: "",
             16: "",
             17: "",
             18: "",
             19: "",
             20: "di",
             21: "choi",
             22: "chao",
             23: "",
             24: "",
             25: "",
             26: "",
             27: "",
             28: "",
             29: "",
             30: "",
             }

prev_time = datetime.datetime.now()

sign_arr = np.empty(0)
pred_count = 0
result_arr = []
max_empty_hand_frame = 30
empty_hand_frame = 0
current_result = 88
font_path = "Disney.ttf"
result = 0

# Define a deque to store the last N results for smoothing
N = 10  # Size of the sliding window
result_buffer = collections.deque(maxlen=N)

while True:
    while len(data) < payload_size:
        data += client_socket.recv(4096)

    packed_msg_size = data[:payload_size]
    data = data[payload_size:]
    msg_size = struct.unpack("<L", packed_msg_size)[0]

    while len(data) < msg_size:
        data += client_socket.recv(4096)

    frame_data = data[:msg_size]
    data = data[msg_size:]

    # Giải mã hình ảnh
    frame = cv2.imdecode(np.frombuffer(frame_data, dtype=np.uint8), cv2.IMREAD_COLOR)

    # Convert the frame color from BGR to RGB
    frame = cv2.flip(frame, 1)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)


    detections = model(frame)[0]
    frame, result = draw_detections(frame, detections)

    if result != 99:
        result_buffer.append(result)
        empty_hand_frame = 0
    
    if not result:
        empty_hand_frame += 1


    if len(result_buffer) > 0:
        # Use the most common element in the buffer as the stable result
        result = max(set(result_buffer), key=result_buffer.count)
        if result != current_result:
            sign_arr = np.append(sign_arr, label_map[result])
            current_result = result

    if empty_hand_frame == max_empty_hand_frame:
        if result == 0:
            current_result = 88
        else:
            current_result = result
        sign_arr = np.empty(0)
    
    curr_time = datetime.datetime.now()
    delta_time = curr_time - prev_time
    fps = 1 / delta_time.total_seconds()
    prev_time = curr_time

    # Display FPS on the frame
    FPS_COLOR = (153, 255, 204)
    fps_text = f"FPS: {fps:.2f}"
    cv2.putText(frame, fps_text, (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, FPS_COLOR, 2)

    # Create a separate window for displaying the results
    result_window = np.zeros((80, 1000, 3), dtype=np.uint8)
    show_result = numpy_array_to_string(sign_arr)
    cv2.putText(result_window, str(show_result), (10, 50), cv2.FONT_HERSHEY_COMPLEX, 1.5, (255, 255, 255), 2)

    cv2.imshow('Hand Detection', frame)
    cv2.imshow("Result window", result_window)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and destroy all OpenCV windows
client_socket.close()
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [4], line 4
#       2 import struct
#       3 import cv2
# ----> 4 import mediapipe as mp
#       5 import numpy as np
#       6 import datetime
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\__init__.py:17
#      15 from mediapipe.python import *
#      16 import mediapipe.python.solutions as solutions
# ---> 17 import mediapipe.tasks.python as tasks
#      20 del framework
#      21 del gpu
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\tasks\python\__init__.py:17
#       1 # Copyright 2022 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """MediaPipe Tasks API."""
# ---> 17 from . import audio
#      18 from . import components
#      19 from . import core
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\tasks\python\audio\__init__.py:18
#      15 """MediaPipe Tasks Audio API."""
#      17 import mediapipe.tasks.python.audio.core
# ---> 18 import mediapipe.tasks.python.audio.audio_classifier
#      19 import mediapipe.tasks.python.audio.audio_embedder
#      21 AudioClassifier = audio_classifier.AudioClassifier
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\tasks\python\audio\audio_classifier.py:26
#      24 from mediapipe.tasks.cc.components.processors.proto import classifier_options_pb2
#      25 from mediapipe.tasks.python.audio.core import audio_task_running_mode as running_mode_module
# ---> 26 from mediapipe.tasks.python.audio.core import base_audio_task_api
#      27 from mediapipe.tasks.python.components.containers import audio_data as audio_data_module
#      28 from mediapipe.tasks.python.components.containers import classification_result as classification_result_module
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\tasks\python\audio\core\base_audio_task_api.py:25
#      23 from mediapipe.tasks.python.audio.core import audio_record
#      24 from mediapipe.tasks.python.audio.core import audio_task_running_mode as running_mode_module
# ---> 25 from mediapipe.tasks.python.core.optional_dependencies import doc_controls
#      27 _TaskRunner = task_runner_module.TaskRunner
#      28 _Packet = packet_module.Packet
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\tasks\python\core\optional_dependencies.py:20
#      16 # TensorFlow isn't a dependency of mediapipe pip package. It's only
#      17 # required in the API docgen pipeline so we'll ignore it if tensorflow is not
#      18 # installed.
#      19 try:
# ---> 20   from tensorflow.tools.docs import doc_controls
#      21 except ModuleNotFoundError:
#      22   # Replace the real doc_controls.do_not_generate_docs with an no-op
#      23   doc_controls = lambda: None
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py:42
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\__init__.py:96
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      92 @@UNKNOWN_CARDINALITY
#      93 """
#      95 # pylint: disable=unused-import
# ---> 96 from tensorflow.python.data.experimental import service
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:419
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:24
#      22 from tensorflow.python import tf2
#      23 from tensorflow.python.compat import compat
# ---> 24 from tensorflow.python.data.experimental.ops import compression_ops
#      25 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      26 from tensorflow.python.data.experimental.service import _pywrap_utils
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:16
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      20 def compress(element):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\util\structure.py:23
#      20 import six
#      21 import wrapt
# ---> 23 from tensorflow.python.data.util import nest
#      24 from tensorflow.python.framework import composite_tensor
#      25 from tensorflow.python.framework import ops
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\util\nest.py:36
#      16 """## Functions for working with arbitrarily nested sequences of elements.
#      17
#      18 NOTE(mrry): This fork of the `tensorflow.python.util.nest` module
#    (...)
#      31    arrays.
#      32 """
#      34 import six as _six
# ---> 36 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      37 from tensorflow.python.util import _pywrap_utils
#      38 from tensorflow.python.util import nest
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\sparse_tensor.py:24
#      22 from tensorflow.python import tf2
#      23 from tensorflow.python.framework import composite_tensor
# ---> 24 from tensorflow.python.framework import constant_op
#      25 from tensorflow.python.framework import dtypes
#      26 from tensorflow.python.framework import ops
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:25
#      23 from tensorflow.core.framework import types_pb2
#      24 from tensorflow.python.eager import context
# ---> 25 from tensorflow.python.eager import execute
#      26 from tensorflow.python.framework import dtypes
#      27 from tensorflow.python.framework import op_callbacks
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:19
#      15 """Functions called by the generated code to execute an eager-mode op."""
#      17 import six
# ---> 19 from google.protobuf import text_format
#      20 from tensorflow.core.framework import tensor_pb2
#      21 from tensorflow.python import pywrap_tfe
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\text_format.py:56
#      54 from google.protobuf import descriptor
#      55 from google.protobuf import text_encoding
# ---> 56 from google.protobuf import unknown_fields
#      58 # pylint: disable=g-import-not-at-top
#      59 __all__ = ['MessageToString', 'Parse', 'PrintMessage', 'PrintField',
#      60            'PrintFieldValue', 'Merge', 'MessageToBytes']
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\unknown_fields.py:44
#      31 """Contains Unknown Fields APIs.
#      32
#      33 Simple usage example:
#    (...)
#      38     data = unknown_field.data
#      39 """
#      42 from google.protobuf.internal import api_implementation
# ---> 44 if api_implementation._c_module is not None:  # pylint: disable=protected-access
#      45   UnknownFieldSet = api_implementation._c_module.UnknownFieldSet  # pylint: disable=protected-access
#      46 else:
#
# AttributeError: module 'google.protobuf.internal.api_implementation' has no attribute '_c_module'

# %%
import socket
import struct
import cv2
import mediapipe as mp
import numpy as np
import datetime
from ultralytics import YOLO
import collections
from PIL import ImageFont, ImageDraw, Image

# Load the pre-trained YOLOv8n model
model = YOLO(r"runs\detect\train9\weights\best.pt")

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Thiết lập socket client
client_socket = socket.socket()
client_socket.connect(('172.20.10.12', 8000))

# Nhận dữ liệu hình ảnh từ server
data = b""
payload_size = struct.calcsize("<L")

# Initialize MediaPipe drawing utils for drawing hands on the image
mp_drawing = mp.solutions.drawing_utils

def draw_detections(frame, last_detections):
    CONFIDENCE_THRESHOLD = 0.6
    COLOR = (153, 255, 204)
    result = 99
    status = False
    if last_detections is not None:
        for data in last_detections.boxes.data.tolist():
            confidence = data[4]
            if float(confidence) < CONFIDENCE_THRESHOLD:
                continue
            status = True
            xmin, ymin, xmax, ymax = int(data[0]), int(data[1]), int(data[2]), int(data[3])
            cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), COLOR, 2)
            class_id = data[5]
            result = class_id
            text = f"{class_id}, {confidence:.2f}"
            cv2.putText(frame, text, (xmin, ymin - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR, 2)
    return frame, result, status

def numpy_array_to_string(arr):
    return ' '.join(map(str, arr))

def put_vietnamese_text(img, text, position, font_path, font_size, color):
    # Chuyển đổi hình ảnh từ OpenCV sang PIL
    pil_img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(pil_img)
    font = ImageFont.truetype(font_path, font_size)
    draw.text(position, text, font=font, fill=color)

    # Chuyển đổi hình ảnh từ PIL sang OpenCV
    img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    return img

label_map = {0: "Toi",
             1: "",
             2: "com",
             3: "",
             4: "",
             5: "",
             6: "",
             7: "",
             8: "",
             9: "",
             10: "ban",
             11: "",
             12: "",
             13: "",
             14: "an",
             15: "",
             16: "",
             17: "",
             18: "",
             19: "",
             20: "di",
             21: "choi",
             22: "chao",
             23: "",
             24: "",
             25: "",
             26: "",
             27: "",
             28: "",
             29: "",
             30: "",
             }

prev_time = datetime.datetime.now()

sign_arr = np.empty(0)
pred_count = 0
result_arr = []
max_empty_hand_frame = 20
empty_hand_frame = 0
current_result = 88
font_path = "Disney.ttf"
result = 0

# Define a deque to store the last N results for smoothing
N = 10  # Size of the sliding window
result_buffer = collections.deque(maxlen=N)

while True:
    while len(data) < payload_size:
        data += client_socket.recv(4096)

    packed_msg_size = data[:payload_size]
    data = data[payload_size:]
    msg_size = struct.unpack("<L", packed_msg_size)[0]

    while len(data) < msg_size:
        data += client_socket.recv(4096)

    frame_data = data[:msg_size]
    data = data[msg_size:]

    # Giải mã hình ảnh
    frame = cv2.imdecode(np.frombuffer(frame_data, dtype=np.uint8), cv2.IMREAD_COLOR)

    #rotate frame
    frame = cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)

    # Convert the frame color from BGR to RGB
    frame = cv2.flip(frame, 1)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    detections = model(frame)[0]
    frame, result, status = draw_detections(frame, detections)

    if result != 99:
        result_buffer.append(result)
        empty_hand_frame = 0
    
    if not status:
        empty_hand_frame += 1

    if len(result_buffer) > 0:
        # Use the most common element in the buffer as the stable result
        result = max(set(result_buffer), key=result_buffer.count)
        if result != current_result:
            sign_arr = np.append(sign_arr, label_map[result])
            current_result = result

    if empty_hand_frame == max_empty_hand_frame:
        if result == 0:
            current_result = 88
        else:
            current_result = result
        sign_arr = np.empty(0)
    
    curr_time = datetime.datetime.now()
    delta_time = curr_time - prev_time
    fps = 1 / delta_time.total_seconds()
    prev_time = curr_time

    # Display FPS on the frame
    FPS_COLOR = (153, 255, 204)
    fps_text = f"FPS: {fps:.2f}"
    cv2.putText(frame, fps_text, (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, FPS_COLOR, 2)

    # Create a separate window for displaying the results
    result_window = np.zeros((80, 1000, 3), dtype=np.uint8)
    show_result = numpy_array_to_string(sign_arr)
    cv2.putText(result_window, str(show_result), (10, 50), cv2.FONT_HERSHEY_COMPLEX, 1.5, (255, 255, 255), 2)

    cv2.imshow('Hand Detection', frame)
    cv2.imshow("Result window", result_window)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the socket and destroy all OpenCV windows
client_socket.close()
cv2.destroyAllWindows()
# Out:
# 0: 640x480 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 H, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 H, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 H, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 B, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 B, 1 H, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 H, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 H, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 I, 11.7ms
# Speed: 1.0ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 I, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 K, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 T, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 T, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 A, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 A, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 A, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 A, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 A, 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 E, 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 E, 1 O, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 E, 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 K, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 B, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 B, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 B, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 A, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 1 N, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# ...
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 1 Q, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 O, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 J, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 1 Q, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 M, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Q, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 A, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
